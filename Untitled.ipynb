# %%
pip install opencv-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2

# %%
import cv2
img = cv2.imread('F:\Computer Vision\opencv-master\samples\data\lena.jpg',0)

print(img)

cv2.imshow('image', img)
cv2.waitKey(5000)
cv2.destroyAllWindows()
# Out:
# [[163 162 161 ... 170 154 130]
#  [162 162 162 ... 173 155 126]
#  [162 162 163 ... 170 155 128]
#  ...
#  [ 43  42  51 ... 103 101  99]
#  [ 41  42  55 ... 103 105 106]
#  [ 42  44  57 ... 102 106 109]]

# %%
import cv2
img = cv2.imread('F:\Computer Vision\opencv-master\samples\data\lena.jpg',-1)

print(img)

cv2.imshow('image', img)
cv2.waitKey(0)
cv2.destroyAllWindows()

cv2.imwrite('lena_copy.png',img)
# Out:
# [[[128 138 225]
#   [127 137 224]
#   [126 136 224]
#   ...
#   [126 145 236]
#   [110 129 220]
#   [ 86 104 197]]
#
#  [[127 137 224]
#   [127 137 224]
#   [127 137 224]
#   ...
#   [130 150 235]
#   [112 132 217]
#   [ 83 102 189]]
#
#  [[127 137 224]
#   [127 137 224]
#   [128 138 225]
#   ...
#   [127 148 230]
#   [112 133 215]
#   [ 85 105 190]]
#
#  ...
#
#  [[ 55  21  82]
#   [ 54  20  81]
#   [ 62  28  92]
#   ...
#   [ 82  71 175]
#   [ 78  68 175]
#   [ 74  65 175]]
#
#  [[ 55  18  80]
#   [ 56  19  81]
#   [ 66  32  96]
#   ...
#   [ 82  69 177]
#   [ 80  71 181]
#   [ 81  72 183]]
#
#  [[ 56  19  81]
#   [ 58  21  83]
#   [ 68  34  98]
#   ...
#   [ 81  68 176]
#   [ 81  72 183]
#   [ 84  74 188]]]
# True

# %%
import cv2
img = cv2.imread('F:\Computer Vision\opencv-master\samples\data\lena.jpg',-1)

cv2.imshow('image', img)

k=cv2.waitKey(0)

if k == 27: #if ecs key presed thn destory the window
    cv2.destroyAllWindows()
elif k ==ord('s'):   #pressed s key thn copy is creted
    cv2.imwrite('lena_copy.png',img)
    cv2.destroyAllWindows()

# %%
import cv2

cap = cv2.VideoCapture(0);

while(True):
    ret,frame = cap.read()      #ret collects true/false
    
    
    cv2.imshow('frame',frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
        
cap.release()
cv2.destroyAllWindows()

# %%
import cv2

cap = cv2.VideoCapture(0)
fourcc = cv2.VideoWriter_fourcc(*'XVID')
out = cv2.VideoWriter('output.avi',fourcc,20.0,(640,480))  #to save vedio

while(cap.isOpened()):
    ret,frame = cap.read()
    #ret collects true/false
    if ret == True:
        
        print(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
        print(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
        
        out.write(frame)
    
        cv2.imshow('frame',frame)
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
    else:
        break
cap.release()
out.release()
cv2.destroyAllWindows()
# Out:
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# ...

# %%
import cv2
img = cv2.imread('F:\Computer Vision\opencv-master\samples\data\lena.jpg',1)

img = cv2.line(img,(0,0), (255,255),(255,0,0),5)  
#line arguments(img,starting_cordinates,ending_cordinated,BGRcolor,thickness)
img = cv2.arrowedLine(img,(0,255), (255,255),(0,255,0),5)

#draw rectangle
img = cv2.rectangle(img, (384,0),(510,128),(0,0,255),5)
img = cv2.rectangle(img, (284,250),(250,100),(255,0,0),-1)

img = cv2.circle(img,(447,63),63,(0,255,0),-1)

#put text on img
font=cv2.FONT_HERSHEY_SIMPLEX
img = cv2.putText(img, 'hey!!', (10,500,),font,4,(255,255,255),10,cv2.LINE_AA)

cv2.imshow('image', img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
##Using numpy zeroes
import numpy as np
import cv2

#img = cv2.imread('F:\Computer Vision\opencv-master\samples\data\lena.jpg',1)

img = np.zeros([912,512,3],np.uint8)

img = cv2.line(img,(0,0), (255,255),(255,0,0),5)  
#line arguments(img,starting_cordinates,ending_cordinated,BGRcolor,thickness)
img = cv2.arrowedLine(img,(0,255), (255,255),(0,255,0),5)

#draw rectangle
img = cv2.rectangle(img, (384,0),(510,128),(0,0,255),5)
img = cv2.rectangle(img, (284,250),(250,100),(255,0,0),-1)

img = cv2.circle(img,(447,63),63,(0,255,0),-1)

#put text on img
font=cv2.FONT_HERSHEY_SIMPLEX
img = cv2.putText(img, 'hey!!', (10,500,),font,4,(255,255,255),10,cv2.LINE_AA)

cv2.imshow('image', img)
cv2.waitKey(0)    
cv2.destroyAllWindows()

# %%
import cv2
cap = cv2.VideoCapture(0)


cap.set(3,700) #setting resolution of camera
cap.set(4,700)

print(cap.get(3))
print(cap.get(4))

while(cap.isOpened()):
    ret,frame = cap.read()
    if ret == True:
        gray = cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)
        cv2.imshow('frame',gray)
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
    else:
        break
cap.release()

cv2.destroyAllWindows()
# Out:
# 640.0
# 480.0

# %%
#date and time
import cv2
import datetime
cap = cv2.VideoCapture(0)
print(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
print(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

while(cap.isOpened()):
    ret,frame = cap.read()
    if ret == True:
        
        font = cv2.FONT_HERSHEY_SIMPLEX
        text = 'Width:' + str(cap.get(3)) + 'Height:' +str(cap.get(4))
        datet = str(datetime.datetime.now())
        frame = cv2.putText(frame, datet, (10,50),font,1,(0,255,0),2,cv2.LINE_AA)
        
        cv2.imshow('frame',frame)
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
    else:
        break
cap.release()
cv2.destroyAllWindows()
# Out:
# 640.0
# 480.0

# %%
#Mouse events
import numpy as np
import cv2

def click_event(event,x,y,flags,param):
    if event == cv2.EVENT_LBUTTONDOWN:
        print(x, ',',y)
        font = cv2.FONT_HERSHEY_SIMPLEX
        strXY = str(x) + ','+str(y)
        cv2.putText(img,strXY,(x,y),font,.5,(255,255,0),2)
        cv2.imshow('image',img)
    
img = np.zeros([912,512,3],np.uint8)
cv2.imshow('image', img)

cv2.setMouseCallback('image', click_event)

cv2.waitKey(0)    
cv2.destroyAllWindows()
# Out:
# 284 , 248
# 115 , 449
# 151 , 274
# 264 , 350
# 354 , 243
# 354 , 250
# 281 , 244
# 245 , 242
# 228 , 219
# 255 , 117
# 222 , 215
# 291 , 497
# 293 , 488
# 287 , 580
# 222 , 556
# 101 , 565
# 98 , 519
# 45 , 477
# 51 , 417
# 52 , 316
# 42 , 238
# 19 , 144
# 130 , 90
# 140 , 172
# 329 , 430
# 429 , 315
# 361 , 305
# 392 , 373
# 441 , 504
# 251 , 442
# 234 , 656
# 213 , 682
# 217 , 699
# 201 , 706
# 189 , 729
# 157 , 734
# 311 , 674
# 349 , 680
# 401 , 698
# 425 , 704
# 338 , 714
# 325 , 700
# 300 , 691
# 286 , 669

# %%
#drawing line from points with click
import numpy as np
import cv2

def click_event(event,x,y,flags,param):
    if event == cv2.EVENT_LBUTTONDOWN:
        cv2.circle(img, (x,y), 3 , (0,0,255), -1)
        points.append((x , y))
        if len(points) >=2:
            cv2.line(img,points[-1],points[-2],(255,0,0),5)
        cv2.imshow('image',img)
    
img = np.zeros([912,512,3],np.uint8)
cv2.imshow('image', img)
points = []

cv2.setMouseCallback('image', click_event)

cv2.waitKey(0)    
cv2.destroyAllWindows()

# %%
import numpy as np
import cv2

def click_event(event,x,y,flags,param):
    if event == cv2.EVENT_LBUTTONDOWN:
        blue = img[x,y,0]
        green = img[x,y,1]
        red = img[x,y,2]
        cv2.circle(img,(x,y),3,(0,0,255),-1)
        mycolorImage = np.zeros((512,512,3),np.uint8)
        
        mycolorImage[:] = [blue,green,red]
        
        cv2.imshow('color',mycolorImage)
        
      
img = cv2.imread('F:\Computer Vision\opencv-master\samples\data\lena.jpg',1)  
cv2.imshow('image',img)
points = []
cv2.setMouseCallback('image',click_event)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2

img = cv2.imread('F:\Computer Vision\opencv-master\samples\data\messi5.jpg')
img2 = cv2.imread('F:\Computer Vision\opencv-master\samples\data\opencv-logo.png') 
print(img.shape)# returns tuple of number of rows, columns and channels
print(img.size)
print(img.dtype)#returns image datatype used for debug
b,g,r=cv2.split(img)
img = cv2.merge((b,g,r))

ball = img[200:340]
img[273:333, 100:160] = ball

img = cv2.resize(img,(512,512))
img2 = cv2.resize(img2,(512,512))

#dst = cv2.add(img,img2);
dst = cv2.addWeighted(img,.8,img2,.2,0);

cv2.imshow('image',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import numpy as np
import cv2

def nothing(x):
    print(x)
img = np.zeros((300,512,3), np.uint8)
cv2.nameedWindow('image') 

cv2.createTrackbar('B','image', 0, 255, nothing)
cv2.createTrackbar('G','image', 0, 255, nothing)
cv2.createTrackbar('R','image', 0, 255, nothing)



while(1):
    cv2.imshow('image',img)
    k = cv.waitKey(1) & 0xFF
    if k == 27:
        break
            
    b = cv.getTrackbarPos('B','image')
    g = cv.getTrackbarPos('G','image')
    r = cv.getTrackbarPos('R','image')
    
    img[:] = [b, g, r]
cv.destroyAllWindows()

# %%
import cv2
import numpy as np

def nothing(x):
    pass
while True:
    
    frame = cv2.imread('F:\Computer Vision\opencv-master\samples\data\smarties.png')
    
    hsv = cv2.cvtColor(frame , cv2.COLOR_BGR2HSV)
    
    l_b = np.array([110,50,50])
    u_b = np.array([130,255,255])

    mask = cv2.inRange(hsv,l_b,u_b)
    res = cv2.bitwise_and(frame,frame,mask = mask)
    
    cv2.imshow("frame",frame)
    cv2.imshow("mask",mask)
    cv2.imshow("res",res)
    key = cv2.waitKey(1)
    if key == 27:
        break;

cv2.destroyAllWindows()

# %%
#single threshold
import cv2
import numpy as np

img = cv2.imread('F:\Computer Vision\opencv-master\samples\data\gradient.png',0)
_,th1 = cv2.threshold(img,127,255,cv2.THRESH_BINARY)

cv2.imshow("Image",img)
cv2.imshow("th1",th1)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#adaptive thresholding
import cv2
import numpy as np

img = cv2.imread('F:\Computer Vision\opencv-master\samples\data\sudoku.png',0)
_,th1 = cv2.threshold(img,127,255,cv2.THRESH_BINARY)#simple threshold
th2 = cv2.adaptiveThreshold(img, 255, cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY, 11, 2)
th3 = cv2.adaptiveThreshold(img, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY, 11, 2)

cv2.imshow("Image",img)
cv2.imshow("th1",th1)
cv2.imshow("th2",th2)
cv2.imshow("th3",th3)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#image blurring an smoothing
import cv2
from matplotlib import pyplot as plt
import numpy as np

img = cv2.imread('F:\Computer Vision\opencv-master\samples\data\opencv-logo.png')
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

kernel = np.ones((5,5), np.float32)/25
dst =  cv2.filter2D(img, -1 , kernel)
blur = cv2.blur(img, (5,5))
gblur = cv2.GaussianBlur(img, (5,5), 0)

titles = ['images','2D convoltuion','blur','GaussianBlur']
images = [img ,dst ,blur,gblur]

for i in range(4):
    plt.subplot(2,2,i+1),plt.imshow(images[i],'gray')
    plt.title(titles[i])
    plt.xticks([]),plt.yticks([])
    
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
#Image Gradient
import cv2
from matplotlib import pyplot as plt
import numpy as np

img = cv2.imread('F:\Computer Vision\opencv-master\samples\data\messi5.jpg',-1)
lap = cv2.Laplacian(img,cv2.CV_64F,ksize =1)
lap = np.uint8(np.absolute(lap))
sobelx = cv2.Sobel(img, cv2.CV_64F, 1, 0)
sobely = cv2.Sobel(img,cv2.CV_64F, 0, 1)

sobelx = np.uint8(np.absolute(sobelx))
sobely = np.uint8(np.absolute(sobely))

titles = ['images','Laplacian' , 'sobelx','sobely']
images = [img ,lap,sobelx,sobely]

for i in range(4):
    plt.subplot(2,2,i+1),plt.imshow(images[i],'gray')
    plt.title(titles[i])
    plt.xticks([]),plt.yticks([])
    
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
import cv2
import numpy as np

def sketch(image):
    #converting_image_to_grayscale
    img_gray=cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
    #blurring_image_to_remove_noise
    img_blur=cv2.GaussianBlur(img_gray,(3,3),0)
    #extracting_edges
    edges=cv2.Canny(img_blur,10,80)
    #applying_threshold_inverse
    ret,mask=cv2.threshold(edges,50,255,cv2.THRESH_BINARY_INV)
    return mask

# capturing_video_from_webcam
cap=cv2.VideoCapture(0)
# constant_image_capture_from_video
while True:
    ret,frame=cap.read()
    cv2.imshow('Live_Sketch',sketch(frame))
    # Key13==ENTER_KEY
    if cv2.waitKey(1)==13:
        break
# releasing_webcam
cap.release()
# destroying_window
cv2.destroyAllWindows()

# %%
import cv2
 
# generate sketch image
def sketch(image):
    # Convert color image to grayscale
    img_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
     
    #make blure image --GaussianBlur(src, ksize, sigmaX[, dst[, sigmaY[, borderType]]])
    img_gray_blur = cv2.GaussianBlur(img_gray, (5,5), 0)
     
    # Extract edges - Canny(image, threshold1, threshold2[, edges[, apertureSize[, L2gradient]]])
    canny_edges = cv2.Canny(img_gray_blur, 60, 90)
     
    #return blure image
    return canny_edges
 
#start video carmera
cap = cv2.VideoCapture(0)
 
while True:
    #read images fro the camera
    responce, frame = cap.read()
     
    if responce == False:
        break
     
    #show the stech image
    cv2.imshow('Live Sketch Drawing', sketch(frame))
     
    # wait for 1ms for kye 'q' no responce then show next image
    if cv2.waitKey(1) & 0xFF == ord('q'): 
        break
         
#Release camera and close all windows
cap.release()
cv2.destroyAllWindows()

# %%
#Image Blending
import cv2
import numpy as np

apple = cv2.imread('F:\Computer Vision\opencv-master\samples\data\apple.jpg', 0)
#apple = cv2.imread('F:\Computer Vision\opencv-master\samples\data\apple.jpg')
orange = cv2.imread('F:\Computer Vision\opencv-master\samples\data\orange.jpg',0)
#orange = cv2.imread('F:\Computer Vision\opencv-master\samples\data\orange.jpg')

print(apple.shape)
print(orange.shape)
apple_orange = np.hstack((apple[:, :256], orange[:,256:]))


cv2.imshow("apple",apple)
cv2.imshow("orange",orange)
cv2.imshow("apple_orange",apple_orange)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-17-074c91641a6b> in <module>
#      13
#      14
# ---> 15 cv2.imshow("apple",apple)
#      16 cv2.imshow("orange",orange)
#      17 cv2.imshow("apple_orange",apple_orange)
#
# error: OpenCV(4.5.1) C:\Users\appveyor\AppData\Local\Temp\1\pip-req-build-oduouqig\opencv\modules\highgui\src\window.cpp:376: error: (-215:Assertion failed) size.width>0 && size.height>0 in function 'cv::imshow'

# %%
import cv2
import numpy as np

img = cv2.imread('F:\Computer Vision\opencv-master\samples\data\opencv-logo.png')
img2 = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

RET, image = cv2.threshold(img2, 170,255,0)
img2 = cv2.Canny(image,30,70)

contour,hierarchy = cv2.findContours(img2,cv2.RETR_EXTERNAL,cv2.CHAIN_APPROX_NONE)
cv2.drawContours(img,contour,-1,(200,100,0),5)


cv2.imshow("img",img)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
##Matching Contours

import cv2
import numpy as np

org_img = cv2.imread("F:\Computer Vision\opencv-master\samples\data\pic3.png")
template_img = cv2.imread("F:\Computer Vision\opencv-master\samples\data\templ.png")

img = cv2.cvtColor(org_img,cv2.COLOR_BGR2GRAY)
img1 = cv2.cvtColor(template_img,cv2.COLOR_BGR2GRAY)

ret,img = cv2,threshold(img,70,255,0)
ret,img1 = cv2,threshold(img1,70,255,0)

contours,hierarchy = cv2.findContours(img1,cv2.RETR_TREE,cv2.CHAIN_APPROX_NONE)
sorted_contours = sorted(contours,key = cv2.contourArea,reverse = True)

template_contours = sorted_countours[1]

contours,hierarchy = cv2.findContours(img,cv2.RETR_TREE,cv2.CHAIN_APPROX_NONE)
sorted_contours = sorted(contours,key = cv2.contourArea,reverse = True)[1:]

smatch = 10
for c in sorted_contours:
    match = (cv2.matchShapes(template_contours, c, 2,0.0))
    print(match)
    if match < smatch:
        cnt = c
        smatch = match

        
cv2.drawContours(org_img,cnt,1,(200,100,0),3)
cv2.imshow("org_img",org_img)
cv2.imshow("template",template_img)
cv2.waitKey()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-31-7e847c5adce3> in <module>
#       8
#       9 img = cv2.cvtColor(org_img,cv2.COLOR_BGR2GRAY)
# ---> 10 img1 = cv2.cvtColor(template_img,cv2.COLOR_BGR2GRAY)
#      11
#      12 ret,img = cv2,threshold(img,70,255,0)
#
# error: OpenCV(4.5.1) C:\Users\appveyor\AppData\Local\Temp\1\pip-req-build-oduouqig\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'

# %%
import cv2
import numpy as np

cap = cv2.VideoCapture(0)
cv2.namedWindow('sketch')

#cv2.createTrackbar('LTC','sketch',0,255,nothing)
#cv2.createTrackbar('UTC','sketch',0,255,nothing)

while True:
    ret, frame = cap.read()
    image = cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)
    image = cv2.GaussianBlur(image,(7,7),0)
    
    #ltc = cv2.getTrackbarPos('LTC','sketch')
    #utc = cv2.getTrackbarPos('UTC','sketch')
    
    image = cv2.Canny(image,10,60)
    ret,image = cv2.threshold(image,50,255,cv2.THRESH_BINARY_INV)
    
    cv2.imshow("original",frame)
    cv2.imshow("sketch",image)
    if cv2.waitKey(1)==ord('q'):
        break
cap.release()
cv2q.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-4047a9e996cd> in <module>
#      24         break
#      25 cap.release()
# ---> 26 cap.destroyAllWindows()
#
# AttributeError: 'cv2.VideoCapture' object has no attribute 'destroyAllWindows'

# %%
import cv2
import numpy as np

cap = cv2.VideoCapture(0)
while True:
    ret,im = cap.read()
    roi = cv2.selectROI("original",im,False,False)
    cv2.destroyAllWindows()
    break

while True:
    ret, frame = cap.read()
    
    image=frame[int(roi[1]):int(roi[1]+roi[3]),(roi[0]):int(roi[0]+roi[2])]

    image = cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)
    image = cv2.GaussianBlur(image,(7,7),0)
    image = cv2.Canny(image,10,70)
    ret,image = cv2.threshold(image,50,255,cv2.THRESH_BINARY_INV)
    
    image = cv2.cvtColor(image,cv2.COLOR_GRAY2BGR)
    
    frame[int(roi[1]):int(roi[1]+roi[3]),
         int(roi[0]):int(roi[0]+roi[2])]=image
    cv2.imshow("original",frame)
    cv2.imshow("sketch",image)
    if cv2.waitKey(1)==ord('q'):
        break
cap.release()
cv2.destroyAllWindows()
